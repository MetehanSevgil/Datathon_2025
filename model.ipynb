# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv")
df.head()
# Out:
#                   event_time event_type   product_id category_id      user_id  \
# 0  2025-06-19 10:23:07+00:00   ADD_CART  PROD_011223   CAT_00054  USER_097562
# 1  2025-06-07 21:34:45+00:00   ADD_CART  PROD_005519   CAT_00144  USER_006535
# 2  2025-06-21 21:29:09+00:00   ADD_CART  PROD_000577   CAT_00273  USER_047199
# 3  2025-06-09 09:10:20+00:00   ADD_CART  PROD_019235   CAT_00442  USER_082028
# 4  2025-06-19 11:13:58+00:00   ADD_CART  PROD_001702   CAT_00025  USER_096574
#
#      user_session  session_value
# 0  SESSION_158779          90.29
# 1  SESSION_029987          16.39
# 2  SESSION_022134          64.27
# 3  SESSION_161308          41.67
# 4  SESSION_182859          86.11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141219 entries, 0 to 141218
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     141219 non-null  object
#  1   event_type     141219 non-null  object
#  2   product_id     141219 non-null  object
#  3   category_id    141219 non-null  object
#  4   user_id        141219 non-null  object
#  5   user_session   141219 non-null  object
#  6   session_value  141219 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 7.5+ MB

# %%
print(df['event_type'].nunique())
print(df["product_id"].nunique())
print(df["category_id"].nunique())
print(df["user_id"].nunique())
print(df["user_session"].nunique())
# Out:
# 4
# 26470
# 448
# 51821
# 70736

# %%
test_df = pd.read_csv("dataset/test.csv")
test_df.head()
# Out:
#                   event_time event_type   product_id category_id      user_id  \
# 0  2025-06-28 10:09:58+00:00   ADD_CART  PROD_015000   CAT_00019  USER_109759
# 1  2025-06-25 11:57:50+00:00   ADD_CART  PROD_023887   CAT_00010  USER_010614
# 2  2025-06-30 14:34:20+00:00   ADD_CART  PROD_022673   CAT_00090  USER_041338
# 3  2025-06-30 22:12:18+00:00   ADD_CART  PROD_004664   CAT_00280  USER_015376
# 4  2025-06-26 16:55:18+00:00   ADD_CART  PROD_027815   CAT_00027  USER_054449
#
#      user_session
# 0  SESSION_164059
# 1  SESSION_109583
# 2  SESSION_171382
# 3  SESSION_137110
# 4  SESSION_146503

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62951 entries, 0 to 62950
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   event_time    62951 non-null  object
#  1   event_type    62951 non-null  object
#  2   product_id    62951 non-null  object
#  3   category_id   62951 non-null  object
#  4   user_id       62951 non-null  object
#  5   user_session  62951 non-null  object
# dtypes: object(6)
# memory usage: 2.9+ MB

# %%
print(test_df['event_type'].nunique())
print(test_df["product_id"].nunique())
print(test_df["category_id"].nunique())
print(test_df["user_id"].nunique())
print(test_df["user_session"].nunique())
# Out:
# 4
# 17450
# 433
# 22665
# 30789

# %%
df["event_time"] = pd.to_datetime(df["event_time"], utc=True)
test_df["event_time"] = pd.to_datetime(test_df["event_time"], utc=True)

df["hour"] = df["event_time"].dt.hour
df["day"] = df["event_time"].dt.day
df["weekday"] = df["event_time"].dt.weekday  # 0 = Pazartesi, 6 = Pazar
df["is_weekend"] = (df["weekday"] >= 5).astype(int) # Hafta sonu kontrolü

test_df["hour"] = test_df["event_time"].dt.hour
test_df["day"] = test_df["event_time"].dt.day
test_df["weekday"] = test_df["event_time"].dt.weekday  # 0 = Pazartesi, 6 = Pazar
test_df["is_weekend"] = (test_df["weekday"] >= 5).astype(int) # Hafta sonu kontrolü

# %%
# --- ) event_type frekansları (her session içinde kaç kez geçmiş) ---
event_counts = df.pivot_table(
    index="user_session", # her oturum (session) için satır oluşturur.
    columns="event_type", # her farklı event_type (VIEW, ADD_CART, vs.) ayrı sütun olur.
    values="event_time", # sayım yapılacak değer (zaman damgası, yani her satır bir event).
    aggfunc="count",  # her session için event sayısını sayar.
    fill_value=0 # olmayan event tipleri 0 olarak doldurulur.
).reset_index() # tabloyu normal DataFrame formatına döndürür.

event_counts_test = test_df.pivot_table(
    index="user_session", # her oturum (session) için satır oluşturur.
    columns="event_type", # her farklı event_type (VIEW, ADD_CART, vs.) ayrı sütun olur.
    values="event_time", # sayım yapılacak değer (zaman damgası, yani her satır bir event).
    aggfunc="count",  # her session için event sayısını sayar.
    fill_value=0 # olmayan event tipleri 0 olarak doldurulur.
).reset_index() # tabloyu normal DataFrame formatına döndürür.

# %%
# --- 2) Ürün ve kategori çeşitliliği + diğer özetler ---
agg_features = df.groupby("user_session").agg(
    user_id=("user_id", "first"),          # session'daki kullanıcı
    n_events=("event_type", "count"),      # toplam event sayısı
    n_products=("product_id", "nunique"),  # benzersiz ürün sayısı
    n_categories=("category_id", "nunique"),  # benzersiz kategori sayısı
    avg_hour=("hour", "mean"),             # ortalama saat
    is_weekend=("is_weekend", "max"),      # hafta sonu mu
    session_value=("session_value", "first")  # hedef değişken
).reset_index()

agg_features_test = test_df.groupby("user_session").agg(
    user_id=("user_id", "first"),          # session'daki kullanıcı
    n_events=("event_type", "count"),      # toplam event sayısı
    n_products=("product_id", "nunique"),  # benzersiz ürün sayısı
    n_categories=("category_id", "nunique"),  # benzersiz kategori sayısı
    avg_hour=("hour", "mean"),             # ortalama işlem saati
    is_weekend=("is_weekend", "max")       # hafta sonu mu
).reset_index()

# %%
# --- 3) Birleştirme ---
train_session = agg_features.merge(event_counts, on="user_session", how="left", sort=False)
test_session = agg_features_test.merge(event_counts_test, on="user_session", how="left", sort=False)

# %%
# --- 4) event_time sütununu datetime'a çevir ---
train_session["hour"] = df["event_time"].dt.hour
train_session["day"] = df["event_time"].dt.day
train_session["weekday"] = df["event_time"].dt.weekday  # 0 = Pazartesi, 6 = Pazar
train_session["is_weekend"] = (df["weekday"] >= 5).astype(int) # Hafta sonu kontrolü

test_session["hour"] = test_df["event_time"].dt.hour
test_session["day"] = test_df["event_time"].dt.day
test_session["weekday"] = test_df["event_time"].dt.weekday  # 0 = Pazartesi, 6 = Pazar
test_session["is_weekend"] = (test_df["event_time"].dt.weekday >= 5).astype(int) # Hafta sonu kontrolü

# %%
# Train için
session_time = df.groupby("user_session")["event_time"].agg(lambda x: (x.max() - x.min()).total_seconds() / 3600).reset_index().rename(columns={"event_time": "session_duration"})
train_session = train_session.merge(session_time, on="user_session", how="left")

# Test için
session_time_test = test_df.groupby("user_session")["event_time"].agg(lambda x: (x.max() - x.min()).total_seconds() / 3600).reset_index().rename(columns={"event_time": "session_duration"})
test_session = test_session.merge(session_time_test, on="user_session", how="left")

# %%
train_session.head()
# Out:
#      user_session      user_id  n_events  n_products  n_categories   avg_hour  \
# 0  SESSION_000000  USER_096031        28          24            20  11.500000
# 1  SESSION_000001  USER_023172         6           5             5   4.166667
# 2  SESSION_000004  USER_065806         1           1             1  10.000000
# 3  SESSION_000005  USER_026492         1           1             1  13.000000
# 4  SESSION_000012  USER_045859         1           1             1   8.000000
#
#    is_weekend  session_value  ADD_CART  BUY  REMOVE_CART  VIEW  hour  day  \
# 0           0         355.80        20    0            8     0    10   19
# 1           1          96.60         2    1            2     1    21    7
# 2           1          30.92         0    0            0     1    21   21
# 3           0          40.09         0    0            0     1     9    9
# 4           0          23.06         0    0            0     1    11   19
#
#    weekday  session_duration
# 0        3        437.046389
# 1        5          2.171667
# 2        5          0.000000
# 3        0          0.000000
# 4        3          0.000000

# %%
test_session.head()
# Out:
#      user_session      user_id  n_events  n_products  n_categories   avg_hour  \
# 0  SESSION_000000  USER_027389        28          27            19  12.035714
# 1  SESSION_000013  USER_096685         2           2             2  19.000000
# 2  SESSION_000022  USER_004363         1           1             1  15.000000
# 3  SESSION_000024  USER_041338         1           1             1  15.000000
# 4  SESSION_000025  USER_052581         3           3             2  12.333333
#
#    is_weekend  ADD_CART  BUY  REMOVE_CART  VIEW  hour  day  weekday  \
# 0           1        23    0            5     0    10   28        5
# 1           0         0    0            0     2    11   25        2
# 2           0         1    0            0     0    14   30        0
# 3           0         0    0            0     1    22   30        0
# 4           0         1    0            2     0    16   26        3
#
#    session_duration
# 0        201.055278
# 1          0.062778
# 2          0.000000
# 3          0.000000
# 4          0.501389

# %%
test_session.shape
# Out:
# (30789, 15)

# %%
from sklearn.model_selection import train_test_split

# Özellikler (hedefi ve kimlik kolonlarını çıkartıyoruz)
feature_cols = ['n_events', 'n_products', 'n_categories', 'avg_hour', 'hour', 'day', 'weekday', 'is_weekend', 'session_duration',
                'ADD_CART', 'BUY', 'REMOVE_CART', 'VIEW']

X = train_session[feature_cols]
y = train_session['session_value']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error, r2_score

model = LGBMRegressor(
    n_estimators=2000,
    learning_rate=0.03,
    max_depth=25,
    random_state=42
)

model.fit(X_train, y_train)

y_pred = model.predict(X_val)

mse = mean_squared_error(y_val, y_pred)

print(f"Validation MSE: {mse:.4f}")
print(f"Validation R^2: {r2_score(y_val, y_pred):.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 739
# [LightGBM] [Info] Number of data points in the train set: 63662, number of used features: 13
# [LightGBM] [Info] Start training from score 42.202568
# Validation MSE: 331.0521
# Validation R^2: 0.8372

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)

# %%
model_ann = Sequential([
    Dense(256, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),

    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),

    Dense(1, activation='linear')  
])

model_ann.compile(
    optimizer=Adam(),
    loss='mse',
    metrics=[tf.keras.metrics.RootMeanSquaredError(), 'mae']
)

# %%
history = model_ann.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=100,
    batch_size=256,
)
# Out:
# Epoch 1/100
# 249/249 [==============================] - 7s 17ms/step - loss: 3315.3523 - root_mean_squared_error: 57.5791 - mae: 40.4788 - val_loss: 3152.8691 - val_root_mean_squared_error: 56.1504 - val_mae: 46.2815
# Epoch 2/100
# 249/249 [==============================] - 3s 12ms/step - loss: 2040.3632 - root_mean_squared_error: 45.1704 - mae: 33.1001 - val_loss: 1488.5248 - val_root_mean_squared_error: 38.5814 - val_mae: 33.3586
# Epoch 3/100
# 249/249 [==============================] - 3s 11ms/step - loss: 1189.7404 - root_mean_squared_error: 34.4926 - mae: 23.8557 - val_loss: 658.9381 - val_root_mean_squared_error: 25.6698 - val_mae: 20.4418
# Epoch 4/100
# 249/249 [==============================] - 3s 11ms/step - loss: 792.2006 - root_mean_squared_error: 28.1461 - mae: 17.4015 - val_loss: 375.2204 - val_root_mean_squared_error: 19.3706 - val_mae: 13.7108
# Epoch 5/100
# Epoch 49/100
# 249/249 [==============================] - 3s 12ms/step - loss: 507.8973 - root_mean_squared_error: 22.5366 - mae: 13.0017 - val_loss: 275.1583 - val_root_mean_squared_error: 16.5879 - val_mae: 11.6397
# Epoch 50/100
# 249/249 [==============================] - 3s 11ms/step - loss: 508.0377 - root_mean_squared_error: 22.5397 - mae: 13.1578 - val_loss: 282.1662 - val_root_mean_squared_error: 16.7978 - val_mae: 11.5295
# Epoch 51/100
# 249/249 [==============================] - 3s 11ms/step - loss: 484.1108 - root_mean_squared_error: 22.0025 - mae: 13.0572 - val_loss: 291.4180 - val_root_mean_squared_error: 17.0710 - val_mae: 11.9948
# Epoch 52/100
# 249/249 [==============================] - 3s 12ms/step - loss: 497.5333 - root_mean_squared_error: 22.3055 - mae: 13.1335 - val_loss: 273.5964 - val_root_mean_squared_error: 16.5407 - val_mae: 11.6233
# Epoch 53/100
# 249/249 [==============================] - 3s 12ms/step - loss: 485.7899 - root_mean_squared_error: 22.0406 - mae: 13.0254 - val_loss: 279.8990 - val_root_mean_squared_error: 16.7302 - val_mae: 11.7191
# Epoch 54/100
# 249/249 [==============================] - 3s 12ms/step - loss: 493.2285 - root_mean_squared_error: 22.2087 - mae: 13.0628 - val_loss: 282.9591 - val_root_mean_squared_error: 16.8214 - val_mae: 11.7147
# Epoch 55/100
# 249/249 [==============================] - 3s 12ms/step - loss: 491.2032 - root_mean_squared_error: 22.1631 - mae: 13.0570 - val_loss: 274.2078 - val_root_mean_squared_error: 16.5592 - val_mae: 11.6202
# Epoch 56/100
# 249/249 [==============================] - 3s 12ms/step - loss: 469.6512 - root_mean_squared_error: 21.6714 - mae: 12.9852 - val_loss: 329.6042 - val_root_mean_squared_error: 18.1550 - val_mae: 11.8334
# Epoch 57/100
# 249/249 [==============================] - 3s 12ms/step - loss: 499.7465 - root_mean_squared_error: 22.3550 - mae: 13.0732 - val_loss: 290.4755 - val_root_mean_squared_error: 17.0433 - val_mae: 11.6931
# Epoch 58/100
# 249/249 [==============================] - 3s 13ms/step - loss: 499.8341 - root_mean_squared_error: 22.3570 - mae: 13.0405 - val_loss: 277.8438 - val_root_mean_squared_error: 16.6686 - val_mae: 11.5832
# Epoch 59/100
# 249/249 [==============================] - 3s 13ms/step - loss: 494.5444 - root_mean_squared_error: 22.2384 - mae: 13.1277 - val_loss: 283.6267 - val_root_mean_squared_error: 16.8412 - val_mae: 11.6589
# Epoch 60/100
# 249/249 [==============================] - 3s 12ms/step - loss: 487.0819 - root_mean_squared_error: 22.0699 - mae: 13.0402 - val_loss: 305.1756 - val_root_mean_squared_error: 17.4693 - val_mae: 11.7424
# Epoch 61/100
# 249/249 [==============================] - 3s 12ms/step - loss: 493.7534 - root_mean_squared_error: 22.2206 - mae: 13.1289 - val_loss: 270.7264 - val_root_mean_squared_error: 16.4538 - val_mae: 11.4617
# Epoch 62/100
# 249/249 [==============================] - 3s 12ms/step - loss: 495.6219 - root_mean_squared_error: 22.2626 - mae: 13.0934 - val_loss: 269.8755 - val_root_mean_squared_error: 16.4279 - val_mae: 11.5298
# Epoch 63/100
# Epoch 78/100
# 249/249 [==============================] - 3s 12ms/step - loss: 487.8277 - root_mean_squared_error: 22.0868 - mae: 13.0862 - val_loss: 276.8970 - val_root_mean_squared_error: 16.6402 - val_mae: 11.5423
# Epoch 79/100
# 249/249 [==============================] - 3s 13ms/step - loss: 478.0575 - root_mean_squared_error: 21.8645 - mae: 13.0015 - val_loss: 281.7610 - val_root_mean_squared_error: 16.7857 - val_mae: 11.6868
# Epoch 80/100
# 249/249 [==============================] - 3s 13ms/step - loss: 485.1749 - root_mean_squared_error: 22.0267 - mae: 13.1106 - val_loss: 278.9358 - val_root_mean_squared_error: 16.7014 - val_mae: 11.5323
# Epoch 81/100
# 249/249 [==============================] - 3s 13ms/step - loss: 481.1925 - root_mean_squared_error: 21.9361 - mae: 13.0579 - val_loss: 267.7362 - val_root_mean_squared_error: 16.3626 - val_mae: 11.5642
# Epoch 82/100
# 249/249 [==============================] - 3s 12ms/step - loss: 466.8113 - root_mean_squared_error: 21.6058 - mae: 13.0746 - val_loss: 273.9277 - val_root_mean_squared_error: 16.5508 - val_mae: 11.5372
# Epoch 83/100
# 249/249 [==============================] - 3s 13ms/step - loss: 486.4313 - root_mean_squared_error: 22.0552 - mae: 13.0688 - val_loss: 308.0434 - val_root_mean_squared_error: 17.5512 - val_mae: 11.8404
# Epoch 84/100
# 249/249 [==============================] - 3s 12ms/step - loss: 479.5154 - root_mean_squared_error: 21.8978 - mae: 12.9678 - val_loss: 274.5828 - val_root_mean_squared_error: 16.5705 - val_mae: 11.6523
# Epoch 85/100
# 249/249 [==============================] - 3s 13ms/step - loss: 458.1746 - root_mean_squared_error: 21.4050 - mae: 12.9437 - val_loss: 297.8669 - val_root_mean_squared_error: 17.2588 - val_mae: 11.8548
# Epoch 86/100
# 249/249 [==============================] - 3s 13ms/step - loss: 468.6749 - root_mean_squared_error: 21.6489 - mae: 13.0940 - val_loss: 269.3251 - val_root_mean_squared_error: 16.4111 - val_mae: 11.4868
# Epoch 87/100
# 249/249 [==============================] - 3s 12ms/step - loss: 466.0581 - root_mean_squared_error: 21.5884 - mae: 13.0420 - val_loss: 277.6515 - val_root_mean_squared_error: 16.6629 - val_mae: 11.5954
# Epoch 88/100
# 249/249 [==============================] - 3s 12ms/step - loss: 439.9380 - root_mean_squared_error: 20.9747 - mae: 13.0117 - val_loss: 277.7734 - val_root_mean_squared_error: 16.6665 - val_mae: 11.6687
# Epoch 89/100
# 249/249 [==============================] - 3s 12ms/step - loss: 438.6733 - root_mean_squared_error: 20.9445 - mae: 13.0027 - val_loss: 283.7441 - val_root_mean_squared_error: 16.8447 - val_mae: 11.7632
# Epoch 90/100
# 249/249 [==============================] - 3s 12ms/step - loss: 462.8065 - root_mean_squared_error: 21.5129 - mae: 13.0523 - val_loss: 281.5048 - val_root_mean_squared_error: 16.7781 - val_mae: 11.6790
# Epoch 91/100
# 249/249 [==============================] - 3s 12ms/step - loss: 464.7251 - root_mean_squared_error: 21.5575 - mae: 13.0860 - val_loss: 295.5437 - val_root_mean_squared_error: 17.1914 - val_mae: 11.6626
# Epoch 92/100
# 249/249 [==============================] - 3s 12ms/step - loss: 463.8283 - root_mean_squared_error: 21.5367 - mae: 13.0467 - val_loss: 290.2849 - val_root_mean_squared_error: 17.0377 - val_mae: 11.6740
# Epoch 93/100
# 249/249 [==============================] - 3s 13ms/step - loss: 457.8307 - root_mean_squared_error: 21.3970 - mae: 13.0589 - val_loss: 301.2817 - val_root_mean_squared_error: 17.3575 - val_mae: 11.8217
# Epoch 94/100
# 249/249 [==============================] - 3s 12ms/step - loss: 474.0137 - root_mean_squared_error: 21.7719 - mae: 13.0499 - val_loss: 274.8109 - val_root_mean_squared_error: 16.5774 - val_mae: 11.5590
# Epoch 95/100
# 249/249 [==============================] - 3s 12ms/step - loss: 468.8281 - root_mean_squared_error: 21.6524 - mae: 13.0866 - val_loss: 273.4441 - val_root_mean_squared_error: 16.5361 - val_mae: 11.4864
# Epoch 96/100
# 249/249 [==============================] - 3s 12ms/step - loss: 459.3224 - root_mean_squared_error: 21.4318 - mae: 13.0269 - val_loss: 278.1689 - val_root_mean_squared_error: 16.6784 - val_mae: 11.6261
# Epoch 97/100
# 249/249 [==============================] - 3s 11ms/step - loss: 468.7473 - root_mean_squared_error: 21.6506 - mae: 13.0412 - val_loss: 296.4515 - val_root_mean_squared_error: 17.2178 - val_mae: 11.8031
# Epoch 98/100
# 249/249 [==============================] - 3s 12ms/step - loss: 484.7915 - root_mean_squared_error: 22.0180 - mae: 13.1101 - val_loss: 281.1991 - val_root_mean_squared_error: 16.7690 - val_mae: 11.5945
# Epoch 99/100
# 249/249 [==============================] - 3s 12ms/step - loss: 463.3099 - root_mean_squared_error: 21.5246 - mae: 12.9820 - val_loss: 273.8696 - val_root_mean_squared_error: 16.5490 - val_mae: 11.5809
# Epoch 100/100
# 249/249 [==============================] - 3s 13ms/step - loss: 452.2939 - root_mean_squared_error: 21.2672 - mae: 13.0189 - val_loss: 276.4221 - val_root_mean_squared_error: 16.6259 - val_mae: 11.5343

# %%
y_pred = model_ann.predict(X_val_scaled)

from sklearn.metrics import r2_score
import numpy as np

rmse = np.sqrt(np.mean((y_val - y_pred.flatten())**2))
r2   = r2_score(y_val, y_pred)

print(f"Validation RMSE: {rmse:.4f}")
print(f"Validation R^2: {r2:.4f}")
# Out:
# 222/222 [==============================] - 1s 3ms/step
# Validation RMSE: 16.6259
# Validation R^2: 0.8641

# %%
X_test = test_session[feature_cols]

test_pred = model.predict(X_test)

submission_df = pd.DataFrame({
    'user_session': test_session['user_session'],
    'session_value': test_pred
})

# %%
X_test_scaled = scaler.transform(X_test)

test_pred_ann = model_ann.predict(X_test_scaled)

submission_df_ann = pd.DataFrame({
    'user_session': test_session['user_session'],
    'session_value': test_pred_ann.flatten()
})
# Out:
# 963/963 [==============================] - 3s 3ms/step

# %%
original_order = test_df[["user_session"]].drop_duplicates()
submission_df = original_order.merge(submission_df, on="user_session", how="left")

submission_df.to_csv("sample_submission.csv", index=False)
print("sample_submission.csv dosyası kaydedildi ✅")
# Out:
# sample_submission.csv dosyası kaydedildi ✅

# %%
original_order = test_df[["user_session"]].drop_duplicates()
submission_df = original_order.merge(submission_df_ann, on="user_session", how="left")

submission_df.to_csv("sample_submission_ann.csv", index=False)
print("sample_submission_ann.csv dosyası kaydedildi ✅")
# Out:
# sample_submission_ann.csv dosyası kaydedildi ✅
